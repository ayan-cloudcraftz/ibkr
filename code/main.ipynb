# %%
from ib_insync import *
from ipynb.fs.full.getMarketData import getOptionPrice
import pandas as pd
util.startLoop()

# %% [markdown]
# Build connection with IBKR

# %%
ib = IB()
ib.connect('127.0.0.1', 7497,  clientId=1000)
# Out:
# <IB connected to 127.0.0.1:7497 clientId=1006>

# %% [markdown]
# Creating the Contract for option chain data

# %%
cd = Contract(symbol='SPX', secType='OPT', exchange='SMART', currency='USD', lastTradeDateOrContractMonth='20240212', right='C', multiplier='100')
qcd = ib.qualifyContracts(cd)
print(qcd)
# Out:
# [Contract(secType='OPT', conId=672340652, symbol='SPX', lastTradeDateOrContractMonth='20240212', strike=1200.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='SPXW  240212C01200000', tradingClass='SPXW'), Contract(secType='OPT', conId=672340658, symbol='SPX', lastTradeDateOrContractMonth='20240212', strike=1400.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='SPXW  240212C01400000', tradingClass='SPXW'), Contract(secType='OPT', conId=672340664, symbol='SPX', lastTradeDateOrContractMonth='20240212', strike=1600.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='SPXW  240212C01600000', tradingClass='SPXW'), Contract(secType='OPT', conId=672340669, symbol='SPX', lastTradeDateOrContractMonth='20240212', strike=1800.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='SPXW  240212C01800000', tradingClass='SPXW'), Contract(secType='OPT', conId=672340677, symbol='SPX', lastTradeD
# ...

# %% [markdown]
# Getting data for all the strikes

# %%
for contract in qcd:
    print(f"Market data searching for {contract.conId}...")
    appData = getOptionPrice(contract=contract)
# Out:
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usopt
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# Market data searching for 672340652...
# ERROR 1 10090 Part of requested market data is not subscribed. Subscription-independent ticks are still active.SPX S&P 500 Stock Index/TOP/ALL
# ERROR 1 10167 Requested market data is not subscribed. Displaying delayed market data.
# tickPrice. reqId: 1, tickType: DELAYED_CLOSE, price: 3821.85, attribs: CanAutoExecute: 0, PastLimit: 0, PreOpen: 0
# tickPrice. reqId: 1, tickType: DELAYED_LAST, price: -1.0, attribs: CanAutoExecute: 0, PastLimit: 0, PreOpen: 0
# tickPrice. reqId: 1, tickType: DELAYED_BID, price: -1.0, attribs: CanAutoExecute: 0, PastLimit: 0, PreOpen: 0
# ...
